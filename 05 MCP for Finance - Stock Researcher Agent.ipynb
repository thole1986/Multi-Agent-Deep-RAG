# %% [markdown]
# ## MCP for Finance - Stock Researcher Agent

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Yahoo Finance Research Tool

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
from dotenv import load_dotenv
load_dotenv()

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent
from langchain_core.messages import HumanMessage

from langchain_core.tools import tool
from langchain.agents.middleware import TodoListMiddleware

import subprocess
import sys

# %%
@tool
def finance_researcher(query):
    """Research stocks using Yahoo Finance MCP async function.
    Call this tool whereever you need to answer finance related question"""

    code = f"""
import asyncio
from scripts.yahoo_mcp import finance_research
asyncio.run(finance_research("{query}"))
"""
    result = subprocess.run([sys.executable, '-c', code], capture_output=True, text=True)

    return result.stdout

# %%
query = "What is the current stock price and recent performance of Apple (AAPL)? Also show me the latest news."
response = finance_researcher.invoke({'query': query})

# %%
print(response)
# Out:
# Loaded 9 tools
# Tools available: ['get_historical_stock_prices', 'get_stock_info', 'get_yahoo_finance_news', 'get_stock_actions', 'get_financial_statement', 'get_holder_info', 'get_option_expiration_dates', 'get_option_chain', 'get_recommendations']
# Here's the information about Apple (AAPL):
#
# **Current Stock Price:**
# *   **Current Price:** $278.78
# *   **Previous Close:** $277.18
# *   **Change Today:** +$1.60 (+0.58%)
#
# **Recent Performance (Last Month):**
# Over the last month, Apple's stock has shown a positive trend:
# *   **Starting Price (November 11, 2025):** $275.25
# *   **Current Price (December 10, 2025):** $278.78
# *   **Overall Change in the Last Month:** +$3.53 (+1.28%)
#
# During this period, the stock traded within a range:
# *   **Highest Close:** $286.19 (December 2, 2025)
# *   **Lowest Close:** $266.25 (November 20, 2025)
#
# **Latest News:**
# Here are some of the latest news headlines concerning Apple:
#
# *   **UBS Reiterates Neutral on Apple (AAPL) as Interest in Apple Intelligence and Foldables Rises**
#     *   *Summary:* UBS analyst David Vogt reiterated a "Neutral" rating on Apple with a $280.00 price target, citing rising interest in Apple Intelligence and foldables.
#     *   *URL:* https://finance.yahoo.com/news/ubs-reiterates-neutral-apple-aapl-093850512.html
#
# *   **Did Apple’s Executive Overhaul Around AI, Regulation and ESG Just Shift Its (AAPL) Investment Narrative?**
#     *   *Summary:* Apple has announced leadership transitions, including changes in legal and AI leadership, which could impact the company's investment narrative.
#     *   *URL:* https://finance.yahoo.com/news/did-apple-executive-overhaul-around-231425875.html

# %% [markdown]
# ### Stock Researcher Agent

# %% [markdown]
# #### System Prompt

# %%
system_prompt = """You are a professional stock research analyst specializing in financial analysis.

**Your Responsibilities:**
1. Analyze stock performance and financial metrics
2. Research company fundamentals
3. Provide data-driven investment recommendations
4. You must use available tools to answer user queries

**Analysis Framework:**
- Company name and ticker symbol
- Current stock price
- Key metrics: P/E ratio, Market Cap, Revenue
- Financial health assessment
- Clear recommendation: Buy, Hold, or Sell

**Important Guidelines:**
- Only respond to finance and stock market related questions
- For non-finance questions, politely decline: "I apologize, but I can only assist with stock market and financial analysis questions. Please ask me about stocks, companies, or financial metrics."
- Always cite specific data and metrics
- Maintain professional and objective tone

Provide concise, actionable insights for investors."""

# %% [markdown]
# #### Create Agent

# %%
from langchain.agents.middleware import TodoListMiddleware

model = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

agent = create_agent(
    model=model,
    tools=[finance_researcher],
    system_prompt=system_prompt,
    middleware=[TodoListMiddleware()]
)

# %%
agent

# %% [markdown]
# #### Run Agent

# %%
response = agent.invoke({'messages': [HumanMessage('what is the weather in mumbai?')]})
response
# Out:
# {'messages': [HumanMessage(content='what is the weather in mumbai?', additional_kwargs={}, response_metadata={}, id='4d95eedf-b3f8-4840-84f1-05dccbcb1437'),
#   AIMessage(content='I apologize, but I can only assist with stock market and financial analysis questions. Please ask me about stocks, companies, or financial metrics.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--4256f7a4-26d3-4331-bae3-491a870b6e6a-0', usage_metadata={'input_tokens': 1416, 'output_tokens': 28, 'total_tokens': 1444, 'input_token_details': {'cache_read': 0}})]}

# %%
query = "Analyze Apple (AAPL) stock and its competitors like MSFT and Google. Present data clearly in the table."

response = agent.invoke({'messages': [HumanMessage(query)]})

# %%
response
# Out:
# {'messages': [HumanMessage(content='Analyze Apple (AAPL) stock and its competitors like MSFT and Google. Present data clearly in the table.', additional_kwargs={}, response_metadata={}, id='d57fdb6a-c061-4bd5-b92b-97ff94d89f1a'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'write_todos', 'arguments': '{"todos": [{"status": "in_progress", "content": "Research Apple (AAPL) stock performance and key financial metrics."}, {"status": "pending", "content": "Research Microsoft (MSFT) stock performance and key financial metrics."}, {"status": "pending", "content": "Research Google (GOOGL) stock performance and key financial metrics."}, {"status": "pending", "content": "Compile all gathered data into a comparative table."}, {"status": "pending", "content": "Assess the financial health of each company."}, {"status": "pending", "content": "Provide investment recommendations for each stock."}]}'}, '__gemini_function_call_thought_signatures__': {'ba007184-0319-4cc0-97ed-c579d54c8660': '...'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--952b1a9e-5258-42b0-a9da-33c38d16b806-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'status': 'in_progress', 'content': 'Research Apple (AAPL) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Research Google (GOOGL) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Compile all gathered data into a comparative table.'}, {'status': 'pending', 'content': 'Assess the financial health of each company.'}, {'status': 'pending', 'content': 'Provide investment recommendations for each stock.'}]}, 'id': 'ba007184-0319-4cc0-97ed-c579d54c8660', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1431, 'output_tokens': 302, 'total_tokens': 1733, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 164}}),
#   ToolMessage(content="Updated todo list to [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.', 'status': 'in_progress'}, {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.', 'status': 'pending'}, {'content': 'Research Google (GOOGL) stock performance and key financial metrics.', 'status': 'pending'}, {'content': 'Compile all gathered data into a comparative table.', 'status': 'pending'}, {'content': 'Assess the financial health of each company.', 'status': 'pending'}, {'content': 'Provide investment recommendations for each stock.', 'status': 'pending'}]", name='write_todos', id='8bda6d18-c379-4d2f-af50-b3ce47c3089b', tool_call_id='ba007184-0319-4cc0-97ed-c579d54c8660'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'finance_researcher', 'arguments': '{"query": "Apple (AAPL) stock performance and key financial metrics"}'}, '__gemini_function_call_thought_signatures__': {'5b53a6d6-107c-4b7f-8de1-0dace2423488': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--8817da4b-0433-4a12-9ac3-3925b647cd20-0', tool_calls=[{'name': 'finance_researcher', 'args': {'query': 'Apple (AAPL) stock performance and key financial metrics'}, 'id': '5b53a6d6-107c-4b7f-8de1-0dace2423488', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1742, 'output_tokens': 67, 'total_tokens': 1809, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 42}}),
#   ToolMessage(content="Loaded 9 tools\nTools available: ['get_historical_stock_prices', 'get_stock_info', 'get_yahoo_finance_news', 'get_stock_actions', 'get_financial_statement', 'get_holder_info', 'get_option_expiration_dates', 'get_option_chain', 'get_recommendations']\nHere's an analysis of Apple (AAPL) stock performance and key financial metrics:\n\n**Current Stock Price and Performance:**\n*   **Current Price:** $278.78\n*   **Day's Range:** $276.44 - $279.75\n*   **52-Week Range:** $169.21 - $288.62\n*   **52-Week Change:** Apple's stock has increased by approximately 11.78% over the last 52 weeks.\n*   **Performance (Last Month):** Based on historical data from November 11, 2025 ($275.25) to December 10, 2025 ($278.78), AAPL has seen an increase of approximately 1.28%.\n\n**Key Financial Metrics:**\n*   **Market Capitalization:** $4.14 Trillion\n*   **Trailing P/E Ratio:** 37.32\n*   **Trailing EPS:** $7.47\n*   **Total Revenue:** $416.16 Billion\n*   **Profit Margins:** 26.915%\n*   **Debt to Equity Ratio:** 152.41% - This indicates that Apple uses a significant amount of debt to finance its assets relative to shareholder equity.\n*   **Return on Equity (ROE):** 171.42% - A very high ROE suggests that the company is highly efficient at generating profits from shareholder investments.\n*   **Dividend Yield:** 0.37%\n*   **Last Dividend Date:** November 10, 2025 ($0.26 per share)\n*   **Last Stock Split:** August 31, 2020 (4-for-1 split)\n\n**Analyst Ratings:**\n*   **Average Analyst Rating:** 2.0 - Buy (on a scale where 1 is Strong Buy and 5 is Sell).\n*   **Target Mean Price:** $285.28\n\n**Summary:**\nApple (AAPL) is currently trading at $278.78. The stock has shown a positive performance over the last year, with an 11.78% increase, and a modest gain of 1.28% in the past month. The company boasts a substantial market capitalization of over $4 trillion and impressive profitability with a profit margin of nearly 27% and a very high return on equity of 171.42%. While the debt-to-equity ratio is relatively high at 152.41%, analysts generally recommend buying the stock, with an average target price suggesting further upside.\n", name='finance_researcher', id='8e35928e-eac9-4e03-9eb1-6b768cfb72c6', tool_call_id='5b53a6d6-107c-4b7f-8de1-0dace2423488'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'write_todos', 'arguments': '{"todos": [{"status": "completed", "content": "Research Apple (AAPL) stock performance and key financial metrics."}, {"status": "in_progress", "content": "Research Microsoft (MSFT) stock performance and key financial metrics."}, {"status": "pending", "content": "Research Google (GOOGL) stock performance and key financial metrics."}, {"status": "pending", "content": "Compile all gathered data into a comparative table."}, {"status": "pending", "content": "Assess the financial health of each company."}, {"status": "pending", "content": "Provide investment recommendations for each stock."}]}'}, '__gemini_function_call_thought_signatures__': {'6bce6390-7443-4d38-8795-8ba74c0edafc': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--5f5767a7-7664-4165-8b12-2ba530dc9400-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'status': 'completed', 'content': 'Research Apple (AAPL) stock performance and key financial metrics.'}, {'status': 'in_progress', 'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Research Google (GOOGL) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Compile all gathered data into a comparative table.'}, {'status': 'pending', 'content': 'Assess the financial health of each company.'}, {'status': 'pending', 'content': 'Provide investment recommendations for each stock.'}]}, 'id': '6bce6390-7443-4d38-8795-8ba74c0edafc', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2489, 'output_tokens': 189, 'total_tokens': 2678, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 51}}),
#   ToolMessage(content="Updated todo list to [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.', 'status': 'in_progress'}, {'content': 'Research Google (GOOGL) stock performance and key financial metrics.', 'status': 'pending'}, {'content': 'Compile all gathered data into a comparative table.', 'status': 'pending'}, {'content': 'Assess the financial health of each company.', 'status': 'pending'}, {'content': 'Provide investment recommendations for each stock.', 'status': 'pending'}]", name='write_todos', id='923fb798-520f-407e-9ea4-099aab68799b', tool_call_id='6bce6390-7443-4d38-8795-8ba74c0edafc'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'finance_researcher', 'arguments': '{"query": "Microsoft (MSFT) stock performance and key financial metrics"}'}, '__gemini_function_call_thought_signatures__': {'353df08e-b2ec-4097-8f38-7b9f2669d3b2': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--9a975daa-775e-4800-a9a1-8ad1cefe077c-0', tool_calls=[{'name': 'finance_researcher', 'args': {'query': 'Microsoft (MSFT) stock performance and key financial metrics'}, 'id': '353df08e-b2ec-4097-8f38-7b9f2669d3b2', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2800, 'output_tokens': 64, 'total_tokens': 2864, 'input_token_details': {'cache_read': 2440}, 'output_token_details': {'reasoning': 38}}),
#   ToolMessage(content='Loaded 9 tools\nTools available: [\'get_historical_stock_prices\', \'get_stock_info\', \'get_yahoo_finance_news\', \'get_stock_actions\', \'get_financial_statement\', \'get_holder_info\', \'get_option_expiration_dates\', \'get_option_chain\', \'get_recommendations\']\nHere\'s an analysis of Microsoft (MSFT) stock performance and key financial metrics:\n\n**Current Stock Price and Performance:**\n*   **Current Price:** $478.56\n*   **52-Week Range:** $344.79 - $555.45\n*   **52-Week Change:** Microsoft\'s stock has seen a **6.45% increase** over the last 52 weeks.\n*   **Past Year Performance (approx. Dec 2024 - Dec 2025):** The stock has risen from approximately $445.70 to $478.56, indicating a positive trend over the last year.\n\n**Key Financial Metrics:**\n*   **Market Capitalization:** Approximately $3.56 Trillion, making Microsoft one of the largest companies globally.\n*   **Valuation:**\n    *   **Trailing P/E Ratio:** 34.01\n    *   **Forward P/E Ratio:** 25.56 (suggests anticipated earnings growth)\n    *   **Trailing EPS:** $14.07\n    *   **Forward EPS:** $18.72 (analysts expect earnings to grow)\n*   **Growth:**\n    *   **Quarterly Revenue Growth:** 18.4%\n    *   **Quarterly Earnings Growth:** 12.5%\n*   **Profitability:**\n    *   **Profit Margins:** 35.71% (indicating strong operational efficiency)\n    *   **Return on Equity (ROE):** 32.24% (demonstrates effective use of shareholder investments to generate profits)\n*   **Dividends:**\n    *   **Annual Dividend Rate:** $3.64\n    *   **Dividend Yield:** 0.76%\n*   **Balance Sheet Health:**\n    *   **Debt to Equity Ratio:** 33.15% (a relatively healthy level of debt in relation to equity)\n\n**Analyst Sentiment:**\n*   **Average Analyst Rating:** "1.3 - Strong Buy" (out of 5, where 1 is a strong buy), indicating a highly positive outlook from analysts.\n\n**Summary:**\nMicrosoft (MSFT) shows strong financial health and positive stock performance over the past year. The company boasts significant market capitalization, robust revenue and earnings growth, impressive profit margins, and a healthy return on equity. Analyst ratings are highly favorable, suggesting continued confidence in its future prospects.\n', name='finance_researcher', id='c9eb9abe-a8c8-4d25-865e-20acb0139285', tool_call_id='353df08e-b2ec-4097-8f38-7b9f2669d3b2'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'write_todos', 'arguments': '{"todos": [{"status": "completed", "content": "Research Apple (AAPL) stock performance and key financial metrics."}, {"status": "completed", "content": "Research Microsoft (MSFT) stock performance and key financial metrics."}, {"status": "in_progress", "content": "Research Google (GOOGL) stock performance and key financial metrics."}, {"status": "pending", "content": "Compile all gathered data into a comparative table."}, {"status": "pending", "content": "Assess the financial health of each company."}, {"status": "pending", "content": "Provide investment recommendations for each stock."}]}'}, '__gemini_function_call_thought_signatures__': {'bfa4c007-a287-47a6-a7da-863b7092074c': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--90cd2777-e42d-497c-9d4f-c05ce1f3fbe3-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'status': 'completed', 'content': 'Research Apple (AAPL) stock performance and key financial metrics.'}, {'status': 'completed', 'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.'}, {'status': 'in_progress', 'content': 'Research Google (GOOGL) stock performance and key financial metrics.'}, {'status': 'pending', 'content': 'Compile all gathered data into a comparative table.'}, {'status': 'pending', 'content': 'Assess the financial health of each company.'}, {'status': 'pending', 'content': 'Provide investment recommendations for each stock.'}]}, 'id': 'bfa4c007-a287-47a6-a7da-863b7092074c', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3498, 'output_tokens': 191, 'total_tokens': 3689, 'input_token_details': {'cache_read': 2514}, 'output_token_details': {'reasoning': 53}}),
#   ToolMessage(content="Updated todo list to [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Google (GOOGL) stock performance and key financial metrics.', 'status': 'in_progress'}, {'content': 'Compile all gathered data into a comparative table.', 'status': 'pending'}, {'content': 'Assess the financial health of each company.', 'status': 'pending'}, {'content': 'Provide investment recommendations for each stock.', 'status': 'pending'}]", name='write_todos', id='1900cc79-b57c-4c5e-b3e9-1c60f75146c1', tool_call_id='bfa4c007-a287-47a6-a7da-863b7092074c'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'finance_researcher', 'arguments': '{"query": "Google (GOOGL) stock performance and key financial metrics"}'}, '__gemini_function_call_thought_signatures__': {'d163b3c6-9166-4f74-b61a-62c2df9ac532': ''}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--809339c6-c727-4a96-9f38-0e5c1b9fc941-0', tool_calls=[{'name': 'finance_researcher', 'args': {'query': 'Google (GOOGL) stock performance and key financial metrics'}, 'id': 'd163b3c6-9166-4f74-b61a-62c2df9ac532', 'type': 'tool_call'}], usage_metadata={'input_tokens': 3809, 'output_tokens': 66, 'total_tokens': 3875, 'input_token_details': {'cache_read': 3353}, 'output_token_details': {'reasoning': 39}}),
#   ToolMessage(content='Loaded 9 tools\nTools available: [\'get_historical_stock_prices\', \'get_stock_info\', \'get_yahoo_finance_news\', \'get_stock_actions\', \'get_financial_statement\', \'get_holder_info\', \'get_option_expiration_dates\', \'get_option_chain\', \'get_recommendations\']\nHere\'s an analysis of Alphabet Inc. (GOOGL) stock performance and key financial metrics:\n\n**Current Stock Price & Performance:**\n*   **Current Price:** $320.21 (as of market close on 2025-12-10)\n*   **Day\'s Range:** $314.68 - $321.31\n*   **52-Week Range:** $140.53 - $328.83\n*   **52-Week Change:** GOOGL has seen a significant increase of approximately 65.18% over the last 52 weeks, outperforming the S&P 500 which changed by 13.04% in the same period.\n*   **All-Time High:** $328.83\n*   **All-Time Low:** $2.40\n\n**Key Financial Metrics:**\n*   **Market Cap:** $3.878 Trillion\n*   **P/E Ratio (Trailing Twelve Months):** 31.64\n*   **Forward P/E:** 28.67\n*   **EPS (Trailing Twelve Months):** $10.12\n*   **Forward EPS:** $11.17\n*   **Revenue Per Share:** $31.71\n*   **Total Revenue (Trailing Twelve Months):** $385.48 Billion\n*   **Gross Margins:** 59.17%\n*   **Profit Margins:** 32.23%\n*   **Return on Equity:** 35.45%\n*   **Debt to Equity:** 11.42%\n*   **Total Cash:** $98.50 Billion\n*   **Free Cashflow:** $47.99 Billion\n\n**Analyst Coverage:**\n*   **Average Analyst Rating:** 1.5 - Strong Buy (based on 53 analyst opinions)\n*   **Target Mean Price:** $327.51\n*   **Target High Price:** $432.00\n*   **Target Low Price:** $185.00\n\n**Performance Overview (Past Year):**\nGOOGL\'s stock has shown strong growth over the past year. From a closing price of approximately $194.64 on 2024-12-11, it has risen to $320.21 on 2025-12-10, representing a substantial gain. The stock has traded significantly above its 52-week low of $140.53 and is currently nearing its 52-week high of $328.83.\n\n**Key Insights:**\n*   Alphabet (GOOGL) has demonstrated robust stock performance over the past year, significantly outperforming the broader market.\n*   The company exhibits strong profitability with healthy gross and profit margins, and an impressive return on equity.\n*   Analysts maintain a "Strong Buy" recommendation, with the current price still below the average target price, suggesting potential for further upside.\n*   Alphabet maintains a strong cash position and a manageable debt-to-equity ratio.\n', name='finance_researcher', id='ea7a4f7a-fcbe-413a-a7a6-65b5049a2692', tool_call_id='d163b3c6-9166-4f74-b61a-62c2df9ac532'),
#   AIMessage(content='', additional_kwargs={'function_call': {'name': 'write_todos', 'arguments': '{"todos": [{"status": "completed", "content": "Research Apple (AAPL) stock performance and key financial metrics."}, {"status": "completed", "content": "Research Microsoft (MSFT) stock performance and key financial metrics."}, {"status": "completed", "content": "Research Google (GOOGL) stock performance and key financial metrics."}, {"status": "in_progress", "content": "Compile all gathered data into a comparative table."}, {"status": "pending", "content": "Assess the financial health of each company."}, {"status": "pending", "content": "Provide investment recommendations for each stock."}]}'}, '__gemini_function_call_thought_signatures__': {'8de68e9a-e3ff-45e1-89aa-29e5dc370153': '...'}}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--0c054466-5573-44a2-b01c-2819a8960757-0', tool_calls=[{'name': 'write_todos', 'args': {'todos': [{'status': 'completed', 'content': 'Research Apple (AAPL) stock performance and key financial metrics.'}, {'status': 'completed', 'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.'}, {'status': 'completed', 'content': 'Research Google (GOOGL) stock performance and key financial metrics.'}, {'status': 'in_progress', 'content': 'Compile all gathered data into a comparative table.'}, {'status': 'pending', 'content': 'Assess the financial health of each company.'}, {'status': 'pending', 'content': 'Provide investment recommendations for each stock.'}]}, 'id': '8de68e9a-e3ff-45e1-89aa-29e5dc370153', 'type': 'tool_call'}], usage_metadata={'input_tokens': 4678, 'output_tokens': 210, 'total_tokens': 4888, 'input_token_details': {'cache_read': 3437}, 'output_token_details': {'reasoning': 72}}),
#   ToolMessage(content="Updated todo list to [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Google (GOOGL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Compile all gathered data into a comparative table.', 'status': 'in_progress'}, {'content': 'Assess the financial health of each company.', 'status': 'pending'}, {'content': 'Provide investment recommendations for each stock.', 'status': 'pending'}]", name='write_todos', id='dac7ca80-eef5-479c-a99e-f8b8275da467', tool_call_id='8de68e9a-e3ff-45e1-89aa-29e5dc370153'),
#   AIMessage(content=[{'type': 'text', 'text': 'Here\'s a comparative analysis of Apple (AAPL), Microsoft (MSFT), and Google (GOOGL):\n\n### Stock Performance and Key Financial Metrics Comparison\n\n| Metric                    | Apple (AAPL)          | Microsoft (MSFT)        | Google (GOOGL)          |\n| :------------------------ | :-------------------- | :---------------------- | :---------------------- |\n| **Current Stock Price**   | $278.78               | $478.56                 | $320.21                 |\n| **52-Week Change**        | 11.78%                | 6.45%                   | 65.18%                  |\n| **Market Cap**            | $4.14 Trillion        | $3.56 Trillion          | $3.878 Trillion         |\n| **Trailing P/E Ratio**    | 37.32                 | 34.01                   | 31.64                   |\n| **Total Revenue**         | $416.16 Billion       | N/A (High growth noted) | $385.48 Billion         |\n| **Profit Margins**        | 26.915%               | 35.71%                  | 32.23%                  |\n| **Debt to Equity Ratio**  | 152.41%               | 33.15%                  | 11.42%                  |\n| **Return on Equity (ROE)**| 171.42%               | 32.24%                  | 35.45%                  |\n| **Average Analyst Rating**| 2.0 (Buy)             | 1.3 (Strong Buy)        | 1.5 (Strong Buy)        |\n\n### Financial Health Assessment and Recommendations\n\n**Apple (AAPL)**\n*   **Financial Health:** Apple demonstrates robust profitability with a high ROE of 171.42% and strong profit margins. However, its debt-to-equity ratio of 152.41% is relatively high compared to its peers, indicating a significant reliance on debt financing. The P/E ratio of 37.32 is also higher than its competitors, suggesting a premium valuation.\n*   **Recommendation:** **Hold**. While Apple is a strong company with significant market presence and profitability, its higher debt-to-equity and P/E ratio compared to its peers warrant a cautious approach. The stock has shown positive performance, but potential investors should monitor debt levels and valuation.\n\n**Microsoft (MSFT)**\n*   **Financial Health:** Microsoft exhibits strong financial health with impressive profit margins of 35.71% and a healthy return on equity of 32.24%. Its debt-to-equity ratio of 33.15% is significantly lower than Apple\'s, indicating a more conservative capital structure. The P/E ratio of 34.01 is competitive. Analysts have a "Strong Buy" rating, reflecting confidence in its growth prospects.\n*   **Recommendation:** **Buy**. Microsoft demonstrates excellent financial stability, strong profitability, and a more favorable debt profile compared to Apple. Its consistent growth and strong analyst sentiment make it an attractive investment.\n\n**Google (GOOGL)**\n*   **Financial Health:** Google showcases exceptional financial health, highlighted by its impressive 52-week change of 65.18%, robust profit margins of 32.23%, and a strong ROE of 35.45%. Notably, its debt-to-equity ratio is very low at 11.42%, indicating a highly conservative and stable financial position. The P/E ratio of 31.64 is the lowest among the three, suggesting a potentially more attractive valuation.\n*   **Recommendation:** **Buy**. Google\'s strong growth, superior financial health with minimal debt, high profitability, and a relatively attractive valuation make it a compelling "Strong Buy" recommendation.\n\n---\nI have compiled the data, assessed financial health, and provided recommendations. Now, I will update the To-Do list to mark these tasks as completed.', 'extras': {'signature': '...'}}], additional_kwargs={'function_call': {'name': 'write_todos', 'arguments': '{"todos": [{"status": "completed", "content": "Research Apple (AAPL) stock performance and key financial metrics."}, {"status": "completed", "content": "Research Microsoft (MSFT) stock performance and key financial metrics."}, {"status": "completed", "content": "Research Google (GOOGL) s ...
#   ToolMessage(content="Updated todo list to [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Research Google (GOOGL) stock performance and key financial metrics.', 'status': 'completed'}, {'content': 'Compile all gathered data into a comparative table.', 'status': 'completed'}, {'content': 'Assess the financial health of each company.', 'status': 'completed'}, {'content': 'Provide investment recommendations for each stock.', 'status': 'completed'}]", name='write_todos', id='75ae6f52-38d9-4ba1-acba-372abb360592', tool_call_id='71a43ddf-3850-4d9f-8b08-f2693bfff0a5'),
#   AIMessage(content=[{'type': 'text', 'text': '## Stock Analysis: Apple (AAPL), Microsoft (MSFT), and Google (GOOGL)\n\nThis analysis provides a comparative overview of Apple, Microsoft, and Google, focusing on key financial metrics and offering investment recommendations.\n\n### Comparative Stock Data\n\n| Metric              | Apple (AAPL)           | Microsoft (MSFT)        | Google (GOOGL)          |\n| :------------------ | :--------------------- | :---------------------- | :---------------------- |\n| **Current Price**   | $278.78                | $478.56                 | $320.21                 |\n| **Market Cap**      | $4.14 Trillion         | $3.56 Trillion          | $3.878 Trillion         |\n| **Trailing P/E**    | 37.32                  | 34.01                   | 31.64                   |\n| **Total Revenue**   | $416.16 Billion        | N/A (Quarterly Revenue Growth: 18.4%) | $385.48 Billion         |\n| **Profit Margins**  | 26.915%                | 35.71%                  | 32.23%                  |\n| **Debt to Equity**  | 152.41%                | 33.15%                  | 11.42%                  |\n| **Return on Equity**| 171.42%                | 32.24%                  | 35.45%                  |\n| **52-Week Change**  | +11.78%                | +6.45%                  | +65.18%                 |\n| **Analyst Rating**  | 2.0 - Buy              | 1.3 - Strong Buy        | 1.5 - Strong Buy        |\n| **Target Mean Price**| $285.28                | N/A                     | $327.51                 |\n\n*Note: Some data points for Microsoft\'s total revenue were not directly available in the provided output, but quarterly revenue growth was noted.*\n\n### Financial Health Assessment and Recommendations\n\n**Apple (AAPL)**\n\n*   **Financial Health:** Apple demonstrates strong profitability with high profit margins (26.915%) and an exceptional Return on Equity (ROE) of 171.42%. Its market capitalization is the highest among the three. However, its Debt to Equity ratio of 152.41% is significantly higher compared to its peers, indicating a greater reliance on debt financing.\n*   **Recommendation:** **Hold**. While Apple exhibits strong profitability and analyst "Buy" ratings, the higher debt-to-equity ratio warrants caution. Investors should monitor debt management. The stock has shown positive, albeit more modest, 52-week growth compared to Google.\n\n**Microsoft (MSFT)**\n\n*   **Financial Health:** Microsoft presents a very healthy financial profile with strong profit margins (35.71%), a solid Return on Equity (32.24%), and a very manageable Debt to Equity ratio (33.15%). The company shows robust quarterly revenue growth of 18.4% and quarterly earnings growth of 12.5%.\n*   **Recommendation:** **Buy**. Microsoft\'s strong financial health, impressive growth metrics, and "Strong Buy" analyst consensus make it an attractive investment. Its balanced financial structure and consistent performance offer a compelling case for continued growth.\n\n**Google (GOOGL)**\n\n*   **Financial Health:** Google showcases excellent financial health with strong profit margins (32.23%), a healthy Return on Equity (35.45%), and a remarkably low Debt to Equity ratio (11.42%). The company has a substantial cash position ($98.50 Billion) and has demonstrated significant 52-week stock performance (+65.18%).\n*   **Recommendation:** **Buy**. Google\'s robust financial position, impressive stock growth, and "Strong Buy" analyst ratings highlight its strong market position and future potential. Its low debt and high profitability make it a financially sound investment.\n\n### Conclusion\n\nAll three companies are technology giants with strong market positions. Microsoft and Google, however, show more robust financial health with lower debt levels and comparable or better profitability metrics, coupled with strong analyst sentiment. Apple, while highly profitable, has a higher debt burden that investors should consider.\n\nThis analysi ...
#  'todos': [{'content': 'Research Apple (AAPL) stock performance and key financial metrics.',
#    'status': 'completed'},
#   {'content': 'Research Microsoft (MSFT) stock performance and key financial metrics.',
#    'status': 'completed'},
#   {'content': 'Research Google (GOOGL) stock performance and key financial metrics.',
#    'status': 'completed'},
#   {'content': 'Compile all gathered data into a comparative table.',
#    'status': 'completed'},
#   {'content': 'Assess the financial health of each company.',
#    'status': 'completed'},
#   {'content': 'Provide investment recommendations for each stock.',
#    'status': 'completed'}]}

# %%
from IPython.display import display, Markdown

display(Markdown(response['messages'][-1].text))
# Out:
# ## Stock Analysis: Apple (AAPL), Microsoft (MSFT), and Google (GOOGL)
#
# This analysis provides a comparative overview of Apple, Microsoft, and Google, focusing on key financial metrics and offering investment recommendations.
#
# ### Comparative Stock Data
#
# | Metric              | Apple (AAPL)           | Microsoft (MSFT)        | Google (GOOGL)          |
# | :------------------ | :--------------------- | :---------------------- | :---------------------- |
# | **Current Price**   | $278.78                | $478.56                 | $320.21                 |
# | **Market Cap**      | $4.14 Trillion         | $3.56 Trillion          | $3.878 Trillion         |
# | **Trailing P/E**    | 37.32                  | 34.01                   | 31.64                   |
# | **Total Revenue**   | $416.16 Billion        | N/A (Quarterly Revenue Growth: 18.4%) | $385.48 Billion         |
# | **Profit Margins**  | 26.915%                | 35.71%                  | 32.23%                  |
# | **Debt to Equity**  | 152.41%                | 33.15%                  | 11.42%                  |
# | **Return on Equity**| 171.42%                | 32.24%                  | 35.45%                  |
# | **52-Week Change**  | +11.78%                | +6.45%                  | +65.18%                 |
# | **Analyst Rating**  | 2.0 - Buy              | 1.3 - Strong Buy        | 1.5 - Strong Buy        |
# | **Target Mean Price**| $285.28                | N/A                     | $327.51                 |
#
# *Note: Some data points for Microsoft's total revenue were not directly available in the provided output, but quarterly revenue growth was noted.*
#
# ### Financial Health Assessment and Recommendations
#
# **Apple (AAPL)**
#
# *   **Financial Health:** Apple demonstrates strong profitability with high profit margins (26.915%) and an exceptional Return on Equity (ROE) of 171.42%. Its market capitalization is the highest among the three. However, its Debt to Equity ratio of 152.41% is significantly higher compared to its peers, indicating a greater reliance on debt financing.
# *   **Recommendation:** **Hold**. While Apple exhibits strong profitability and analyst "Buy" ratings, the higher debt-to-equity ratio warrants caution. Investors should monitor debt management. The stock has shown positive, albeit more modest, 52-week growth compared to Google.
#
# **Microsoft (MSFT)**
#
# *   **Financial Health:** Microsoft presents a very healthy financial profile with strong profit margins (35.71%), a solid Return on Equity (32.24%), and a very manageable Debt to Equity ratio (33.15%). The company shows robust quarterly revenue growth of 18.4% and quarterly earnings growth of 12.5%.
# *   **Recommendation:** **Buy**. Microsoft's strong financial health, impressive growth metrics, and "Strong Buy" analyst consensus make it an attractive investment. Its balanced financial structure and consistent performance offer a compelling case for continued growth.
#
# **Google (GOOGL)**
#
# *   **Financial Health:** Google showcases excellent financial health with strong profit margins (32.23%), a healthy Return on Equity (35.45%), and a remarkably low Debt to Equity ratio (11.42%). The company has a substantial cash position ($98.50 Billion) and has demonstrated significant 52-week stock performance (+65.18%).
# *   **Recommendation:** **Buy**. Google's robust financial position, impressive stock growth, and "Strong Buy" analyst ratings highlight its strong market position and future potential. Its low debt and high profitability make it a financially sound investment.
#
# ### Conclusion
#
# All three companies are technology giants with strong market positions. Microsoft and Google, however, show more robust financial health with lower debt levels and comparable or better profitability metrics, coupled with strong analyst sentiment. Apple, while highly profitable, has a higher debt burden that investors should consider.
#
# This analysis is based on available data and should be used as a starting point for further due diligence.
